# %%
import imageio
import imgaug as ia
# %matplotlib inline

image = imageio. imread('C:/Users/CES/[JupyterProject]/augmentation/images/210216_002.jpg')
print(image.shape)

ia.imshow(image)
# Out:
# (256, 256, 3)

# %%
from imgaug.augmentables.polys import Polygon, PolygonsOnImage
